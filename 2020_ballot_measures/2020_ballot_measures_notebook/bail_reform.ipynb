# %% [markdown]
# ## Campaign contributions for and against rent control initiative

# %%
import pandas as pd

# %%
bail_1 = pd.read_csv("bail_reform_1.csv")

# %%
bail_2 = pd.read_csv("bail_reform_2.csv")

# %%
bail = pd.concat([bail_1, bail_2])

# %%
bail
# Out:
#                                   name_of_contributor payment_type  \
# 0                        SUN SURETY INSURANCE COMPANY     MONETARY
# 1                           BANKERS INSURANCE COMPANY     MONETARY
# 2                                   AIA HOLDINGS INC.     MONETARY
# 3         UNIVERSAL FIRE & CASUALTY INSURANCE COMPANY     MONETARY
# 4            LEXINGTON NATIONAL INSURANCE CORPORATION     MONETARY
# 5                             AMERICAN SURETY COMPANY     MONETARY
# 6                           SEAVIEW INSURANCE COMPANY     MONETARY
# 7                           BANKERS INSURANCE COMPANY     MONETARY
# 8                        SUN SURETY INSURANCE COMPANY     MONETARY
# 9                                   AIA HOLDINGS INC.     MONETARY
# 10               UNITED STATES FIRE INSURANCE COMPANY     MONETARY
# 11        UNIVERSAL FIRE & CASUALTY INSURANCE COMPANY     MONETARY
# 0   SEIU CALIFORNIA STATE COUNCIL (NONPROFIT 501(C...     MONETARY
# 1                                       PATTY QUILLIN     MONETARY
# 2   NEXTGEN CALIFORNIA SPONSORED BY NEXTGEN CLIMAT...     MONETARY
# 3                          ACTION NOW INITIATIVE, LLC     MONETARY
# 4                                    LYNN SCHUSTERMAN     MONETARY
#
#               city state    zip  id_number employer    occupation  \
# 0       RAPID CITY    SD  57701        NaN      NaN           NaN
# 1   ST. PETERSBURG    FL  33716  1415528.0      NaN           NaN
# 2        CALABASAS    CA  91302        NaN      NaN           NaN
# 3      HUDSONVILLE    MI  49426        NaN      NaN           NaN
# 4     COCKEYSVILLE    MD  21030        NaN      NaN           NaN
# 5     INDIANAPOLIS    IN  46240   499391.0      NaN           NaN
# 6         CARLSBAD    CA  92011        NaN      NaN           NaN
# 7   ST. PETERSBURG    FL  33716  1415528.0      NaN           NaN
# 8       RAPID CITY    SD  57701        NaN      NaN           NaN
# 9        CALABASAS    CA  91302        NaN      NaN           NaN
# 10      MORRISTOWN    NJ   7962        NaN      NaN           NaN
# 11     HUDSONVILLE    MI  49426        NaN      NaN           NaN
# 0       SACRAMENTO    CA  95814  1372681.0      NaN           NaN
# 1       SANTA CRUZ    CA  95060        NaN     NONE     HOMEMAKER
# 2       SACRAMENTO    CA  95814  1385903.0      NaN           NaN
# 3          HOUSTON    TX  77027        NaN      NaN           NaN
# 4            TULSA    OK  74119        NaN     NONE  PHILANTHROPY
#
#          amount transaction_date filed_date transaction_number  \
# 0       $555.00       12/23/2019  1/30/2020   2439370 - INC141
# 1    $26,214.00       12/26/2019  1/30/2020   2439370 - INC142
# 2    $14,012.00       12/24/2019  1/30/2020   2439370 - INC143
# 3       $464.00       12/27/2019  1/30/2020   2439370 - INC144
# 4   $104,308.40         4/8/2019  7/31/2019    2397590 - INC78
# 5    $40,522.22         4/9/2019  7/31/2019    2397590 - INC79
# 6   $180,518.11        4/12/2019  7/31/2019    2397590 - INC80
# 7   $100,959.02        4/12/2019  7/31/2019    2397590 - INC90
# 8     $2,138.69        4/26/2019  7/31/2019    2397590 - INC92
# 9    $53,966.31        4/26/2019  7/31/2019    2397590 - INC93
# 10   $38,801.03        5/23/2019  7/31/2019    2397590 - INC94
# 11    $1,786.22        5/28/2019  7/31/2019    2397590 - INC96
# 0   $250,000.00        12/6/2019  1/31/2020     2443451 - IDT1
# 1   $250,000.00       12/23/2019  1/31/2020    2443451 - INC12
# 2    $25,000.00       12/27/2019  1/31/2020    2443451 - INC13
# 3   $500,000.00       12/31/2019  1/31/2020    2443451 - INC15
# 4   $250,000.00       12/19/2019  1/31/2020     2443451 - INC9
#
#                                        committee_name position
# 0                        CALIFORNIANS FOR BAIL REFORM   oppose
# 1                        CALIFORNIANS FOR BAIL REFORM   oppose
# 2                        CALIFORNIANS FOR BAIL REFORM   oppose
# 3                        CALIFORNIANS FOR BAIL REFORM   oppose
# 4                        CALIFORNIANS FOR BAIL REFORM   oppose
# 5                        CALIFORNIANS FOR BAIL REFORM   oppose
# 6                        CALIFORNIANS FOR BAIL REFORM   oppose
# 7                        CALIFORNIANS FOR BAIL REFORM   oppose
# 8                        CALIFORNIANS FOR BAIL REFORM   oppose
# 9                        CALIFORNIANS FOR BAIL REFORM   oppose
# 10                       CALIFORNIANS FOR BAIL REFORM   oppose
# 11                       CALIFORNIANS FOR BAIL REFORM   oppose
# 0   END PREDATORY & UNFAIR MONEY BAIL, A COALITION...  support
# 1   END PREDATORY & UNFAIR MONEY BAIL, A COALITION...  support
# 2   END PREDATORY & UNFAIR MONEY BAIL, A COALITION...  support
# 3   END PREDATORY & UNFAIR MONEY BAIL, A COALITION...  support
# 4   END PREDATORY & UNFAIR MONEY BAIL, A COALITION...  support
