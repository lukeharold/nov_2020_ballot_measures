# %% [markdown]
# ## Campaign contributions for and against Prop. 21
#
# Luke Harold
#
# *** current as of Sept. 4, 2020

# %%
import pandas as pd

# %%
committee_1 = pd.read_csv("rent_control_1.csv")

# %%
committee_2 = pd.read_csv("rent_control_2.csv")

# %%
committee_3 = pd.read_csv("rent_control_3.csv")

# %%
committee_4 = pd.read_csv("rent_control_4.csv")

# %%
committee_5 = pd.read_csv("rent_control_5.csv")

# %%
contribs = pd.concat([committee_1, committee_2, committee_3, committee_4, committee_5])

# %%
contribs.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 4511 entries, 0 to 676
# Data columns (total 15 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   name_of_contributor  4466 non-null   object
#  1   payment_type         4510 non-null   object
#  2   city                 4504 non-null   object
#  3   state                4501 non-null   object
#  4   zip                  4501 non-null   object
#  5   id_number            7 non-null      object
#  6   employer             3277 non-null   object
#  7   occupation           3509 non-null   object
#  8   amount               4510 non-null   float64
#  9   transaction_date     4510 non-null   object
#  10  filed_date           4510 non-null   object
#  11  transaction_number   4510 non-null   object
#  12  committee_name       4466 non-null   object
#  13  position             4466 non-null   object
#  14  name_of_contibutor   44 non-null     object
# ...

# %%
## cities where the most contributors come from

# %%
contribs.city.value_counts().reset_index()
# Out:
#              index  city
# 0      LOS ANGELES   834
# 1    SAN FRANCISCO   259
# 2         BROOKLYN    79
# 3          OAKLAND    69
# 4        SAN DIEGO    68
# ..             ...   ...
# 963    HALTOM CITY     1
# 964    BROOKEVILLE     1
# 965   GRAND RAPIDS     1
# 966   MATTAPOISETT     1
# 967  WHITEFISH BAY     1
#
# [968 rows x 2 columns]

# %%
## contributions from San Diego

# %%
sd_contribs = contribs[contribs.city == "SAN DIEGO"]

# %%
sd_contribs.amount.sum()
# Out:
# 666179.0

# %%
sd_contribs.sort_values("amount", ascending = False)
# Out:
#                                   name_of_contributor payment_type       city  \
# 54      R&V MANAGEMENT CORPORATION AND ITS AFFILIATES     MONETARY  SAN DIEGO
# 151   PATHFINDER PARTNERS, LP AND AFFILIATED ENTITIES     MONETARY  SAN DIEGO
# 382   PATHFINDER PARTNERS, LP AND AFFILIATED ENTITIES     MONETARY  SAN DIEGO
# 383                     KIMBALL, TIREY & ST. JOHN LLP     MONETARY  SAN DIEGO
# 152                     KIMBALL, TIREY & ST. JOHN LLP     MONETARY  SAN DIEGO
# ...                                               ...          ...        ...
# 2536                                  RICARDO SOLTERP     MONETARY  SAN DIEGO
# 2601                                      SEAN CADDEN     MONETARY  SAN DIEGO
# 392                                   RACHELLE VALDEZ     MONETARY  SAN DIEGO
# 2632                                JOSHUA KIMESSMITH     MONETARY  SAN DIEGO
# 1701                                    KARIM GILLIAM     MONETARY  SAN DIEGO
#
# ...
